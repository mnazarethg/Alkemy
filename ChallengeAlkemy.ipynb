# %%
#!pip install requests
import requests
import pandas as pd
import io

# %%
url1 = 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/4207def0-2ff7-41d5-9095-d42ae8207a5d/download/museos_datosabiertos.csv'
#url2 = 'https://datos.gob.ar/dataset/cultura-mapa-cultural-espacios-culturales/archivo/cultura_392ce1a8-ef11-4776-b280-6f1c7fae16ae'
url3 = 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/01c6c048-dbeb-44e0-8efa-6944f73715d7/download/biblioteca_popular.csv'

# %%
urlData = requests.get(url1).content
#urlData2 = requests.get(url1).content
urlData3 = requests.get(url3).content
museos = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
#cines = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
biblio_pop = pd.read_csv(io.StringIO(urlData3.decode('utf-8')))

# %%
cines = pd.read_excel('./../../Downloads/cines-03-09-2022.csv.xlsx')

# %%
cines.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observaciones',
#        'Categoría', 'Provincia', 'Departamento', 'Localidad', 'Nombre',
#        'Dirección', 'Piso', 'CP', 'cod_area', 'Teléfono', 'Mail', 'Web',
#        'Información adicional', 'Latitud', 'Longitud', 'TipoLatitudLongitud',
#        'Fuente', 'tipo_gestion', 'Pantallas', 'Butacas', 'espacio_INCAA',
#        'año_actualizacion'],
#       dtype='object')

# %%
museos
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0      6588100            6            6588            NaN
# 1      6077010            6            6077            NaN
# 2      6035010            6            6035            NaN
# 3      6035010            6            6035            NaN
# 4      6049020            6            6049            NaN
# ...        ...          ...             ...            ...
# 1177  90098040           90           90098            NaN
# 1178  90105080           90           90105            NaN
# 1179  90105080           90           90105            NaN
# 1180  90105070           90           90105            NaN
# 1181  90098040           90           90098            NaN
#
#                                categoria subcategoria     provincia  \
# 0     Espacios de Exhibición Patrimonial       Museos  Buenos Aires
# 1     Espacios de Exhibición Patrimonial       Museos  Buenos Aires
# ...

# %%
museos.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observaciones',
#        'categoria', 'subcategoria', 'provincia', 'localidad', 'nombre',
#        'direccion', 'piso', 'CP', 'cod_area', 'telefono', 'Mail', 'Web',
#        'Latitud', 'Longitud', 'TipoLatitudLongitud', 'Info_adicional',
#        'fuente', 'jurisdiccion', 'año_inauguracion', 'actualizacion'],
#       dtype='object')

# %%
biblio_pop
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observacion  \
# 0     70049060           70           70049          NaN
# 1      2000010            2            2000          NaN
# 2      2000010            2            2000          NaN
# 3      2000010            2            2000          NaN
# 4      2000010            2            2000          NaN
# ...        ...          ...             ...          ...
# 2012  62042560           62           62042          NaN
# 2013  70028010           70           70028          NaN
# 2014  62007080           62           62007          NaN
# 2015  62077010           62           62077          NaN
# 2016  62042360           62           62042          NaN
#
#                   Categoría  Subcategoria                        Provincia  \
# 0     Bibliotecas Populares           NaN                         San Juan
# 1     Bibliotecas Populares           NaN  Ciudad Autónoma de Buenos Aires
# ...
